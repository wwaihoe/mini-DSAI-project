# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set_theme()

# %%
df = pd.read_csv('Prepped dataset.csv')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    male     168    62.0    110     80            1     1      0
# 1   1  20228  female     156    85.0    140     90            3     1      0
# 2   2  18857  female     165    64.0    130     70            3     1      0
# 3   3  17623    male     169    82.0    150    100            1     1      0
# 4   4  17474  female     156    56.0    100     60            1     1      0
#
#    ...  age(year)  age(int_year)  female  male  norm_chl  high_chl  vhigh_chl  \
# 0  ...  50.391781             50       0     1         1         0          0
# 1  ...  55.419178             55       1     0         0         0          1
# 2  ...  51.663014             51       1     0         0         0          1
# 3  ...  48.282192             48       0     1         1         0          0
# 4  ...  47.873973             47       1     0         1         0          0
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age(year)',
#        'age(int_year)', 'female', 'male', 'norm_chl', 'high_chl', 'vhigh_chl',
#        'norm_gluc', 'high_gluc', 'vhigh_gluc'],
#       dtype='object')

# %%
for col in ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'female', 'male', 'norm_chl', 'high_chl', 'vhigh_chl', 'norm_gluc', 'high_gluc', 'vhigh_gluc']:
    df[col] = df[col].astype('category')

# %%
df.dtypes
# Out:
# id                  int64
# age                 int64
# gender           category
# height              int64
# weight            float64
# ap_hi               int64
# ap_lo               int64
# cholesterol      category
# gluc             category
# smoke            category
# alco             category
# active           category
# cardio           category
# age(year)         float64
# age(int_year)       int64
# female           category
# male             category
# norm_chl         category
# high_chl         category
# vhigh_chl        category
# norm_gluc        category
# high_gluc        category
# vhigh_gluc       category
# dtype: object

# %% [markdown]
# #Age

# %%
df['age(year)'].describe()
# Out:
# count    68711.000000
# mean        53.326782
# std          6.762069
# min         29.583562
# 25%         48.375342
# 50%         53.975342
# 75%         58.421918
# max         64.967123
# Name: age(year), dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='age(int_year)', data=df, ax=ax[0])
sb.violinplot(x='age(int_year)', data=df, ax=ax[1])
sb.boxplot(x='age(int_year)', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='age(int_year)'>

# %% [markdown]
# Dataset consists of mostly older adults.

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='age(int_year)', hue='cardio', data=df, ax=ax[0])
sb.violinplot(x='age(int_year)', y='cardio', data=df, ax=ax[1])
sb.boxplot(x='age(int_year)', y='cardio', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='age(int_year)', ylabel='cardio'>

# %% [markdown]
# People of higher age have a higher chance of having cardiovascular disease.

# %% [markdown]
# #Gender

# %%
sb.countplot(x='female',data=df)
# Out:
# <AxesSubplot:xlabel='female', ylabel='count'>

# %% [markdown]
# dataset consists of mostly females.

# %%
sb.countplot(x='gender',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# gender does not play a significant role in determining presence of cardiovascular disease.

# %% [markdown]
# #Height

# %%
df['height'].describe()
# Out:
# count    68711.000000
# mean       164.359666
# std          8.191164
# min         55.000000
# 25%        159.000000
# 50%        165.000000
# 75%        170.000000
# max        250.000000
# Name: height, dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='height', data=df, ax=ax[0])
sb.violinplot(x='height', data=df, ax=ax[1])
sb.boxplot(x='height', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='height'>

# %% [markdown]
# Height spans a large range with most people being between 150cm and 175cm.

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='height', hue='cardio', data=df, ax=ax[0])
sb.violinplot(x='height', y='cardio', data=df, ax=ax[1])
sb.boxplot(x='height', y='cardio', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='height', ylabel='cardio'>

# %% [markdown]
# Height is not a good indicator of cardiovascular disease.

# %% [markdown]
# #Weight

# %%
df['weight'].describe()
# Out:
# count    68711.000000
# mean        74.117921
# std         14.333281
# min         11.000000
# 25%         65.000000
# 50%         72.000000
# 75%         82.000000
# max        200.000000
# Name: weight, dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='weight', data=df, ax=ax[0])
sb.violinplot(x='weight', data=df, ax=ax[1])
sb.boxplot(x='weight', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='weight'>

# %% [markdown]
# Weight spans a large range with most people weighing between 50kg and 100kg.

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='weight', hue='cardio', data=df, ax=ax[0])
sb.violinplot(x='weight', y='cardio', split=True, data=df, ax=ax[1])
sb.boxplot(x='weight', y='cardio', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='cardio'>

# %% [markdown]
# People with a higher weight have a slightly higher chance of having cardiovascular disease.

# %% [markdown]
# #Blood pressure

# %%
#Systolic BP
df['ap_hi'].describe()
# Out:
# count    68711.000000
# mean       126.669296
# std         16.708332
# min         16.000000
# 25%        120.000000
# 50%        120.000000
# 75%        140.000000
# max        240.000000
# Name: ap_hi, dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='ap_hi', data=df, ax=ax[0])
sb.violinplot(x='ap_hi', data=df, ax=ax[1])
sb.boxplot(x='ap_hi', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='ap_hi'>

# %%
#Diastolic BP
df['ap_lo'].describe()
# Out:
# count    68711.000000
# mean        81.273115
# std          9.572682
# min          1.000000
# 25%         80.000000
# 50%         80.000000
# 75%         90.000000
# max        182.000000
# Name: ap_lo, dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='ap_lo', data=df, ax=ax[0])
sb.violinplot(x='ap_lo', data=df, ax=ax[1])
sb.boxplot(x='ap_lo', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='ap_lo'>

# %% [markdown]
# Blood pressure measurements are mostly in the tens, which is likely due to the way it was recorded during screening.

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='ap_hi', hue='cardio', data=df, ax=ax[0])
sb.violinplot(x='ap_hi', y='cardio', split=True, data=df, ax=ax[1])
sb.boxplot(x='ap_hi', y='cardio', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='ap_hi', ylabel='cardio'>

# %%
fig,ax = plt.subplots(3,1,figsize=(12,8))
sb.histplot(x='ap_lo', hue='cardio', data=df, ax=ax[0])
sb.violinplot(x='ap_lo', y='cardio', split=True, data=df, ax=ax[1])
sb.boxplot(x='ap_lo', y='cardio', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='ap_lo', ylabel='cardio'>

# %% [markdown]
# Higher blood pressures is a good indicator of cardiovascular disease.

# %% [markdown]
# #Cholesterol

# %%
sb.countplot(x='cholesterol',data=df)
# Out:
# <AxesSubplot:xlabel='cholesterol', ylabel='count'>

# %% [markdown]
# Large majority of people have normal cholesterol levels.

# %%
sb.countplot(x='cholesterol',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='cholesterol', ylabel='count'>

# %% [markdown]
# People with higher cholesterol levels are more likely to have cardiovascular disease.

# %% [markdown]
# #Glucose

# %%
sb.countplot(x='gluc',data=df)
# Out:
# <AxesSubplot:xlabel='gluc', ylabel='count'>

# %% [markdown]
# Large majority have normal glucose levels.

# %%
sb.countplot(x='gluc',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='gluc', ylabel='count'>

# %% [markdown]
# People with higher glucose levels are more likely to have cardiovascular disease.

# %% [markdown]
# #Smoking

# %%
sb.countplot(x='smoke',data=df)
# Out:
# <AxesSubplot:xlabel='smoke', ylabel='count'>

# %% [markdown]
# A small percentage of people smoke.

# %%
sb.countplot(x='smoke',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='smoke', ylabel='count'>

# %% [markdown]
# Smoking is not a good indicator of cardiovascular disease.

# %% [markdown]
# #Alcohol

# %%
sb.countplot(x='alco',data=df)
# Out:
# <AxesSubplot:xlabel='alco', ylabel='count'>

# %% [markdown]
# An even small percentage of people drink regularly.

# %%
sb.countplot(x='alco',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='alco', ylabel='count'>

# %% [markdown]
# Regular drinking is not a good indicator of cardiovascular disease.

# %% [markdown]
# #Activity level

# %%
sb.countplot(x='active',data=df)
# Out:
# <AxesSubplot:xlabel='active', ylabel='count'>

# %% [markdown]
# Most people are active.

# %%
sb.countplot(x='active',hue='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='active', ylabel='count'>

# %% [markdown]
# People who are more active have a slightly lower chance of cardiovascular disease.

# %% [markdown]
# #Presence of cardiovascular disease (Label)

# %%
sb.countplot(x='cardio',data=df)
# Out:
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %% [markdown]
# Even distribution of people who have and have not been diagnosed with cardiovascular disease.
